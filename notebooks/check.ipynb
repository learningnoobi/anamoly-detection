# %%
import pandas as pd
import numpy as np

# %%
path = '../data/train_test_network.csv'
df = pd.read_csv(path, low_memory=False)

# %%
df.head()
# Out:
#           src_ip  src_port         dst_ip  dst_port proto service    duration  \
# 0   192.168.1.37      4444  192.168.1.193     49178   tcp       -  290.371539
# 1  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000102
# 2  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000148
# 3  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000113
# 4  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000130
#
#    src_bytes  dst_bytes conn_state  ...  http_response_body_len  \
# 0     101568       2592        OTH  ...                       0
# 1          0          0        REJ  ...                       0
# 2          0          0        REJ  ...                       0
# 3          0          0        REJ  ...                       0
# 4          0          0        REJ  ...                       0
#
#    http_status_code  http_user_agent  http_orig_mime_types  \
# 0                 0                -                     -
# 1                 0                -                     -
# 2                 0                -                     -
# 3                 0                -                     -
# 4                 0                -                     -
#
#    http_resp_mime_types weird_name  weird_addl  weird_notice  label      type
# 0                     -          -           -             -      1  backdoor
# 1                     -          -           -             -      1  backdoor
# 2                     -          -           -             -      1  backdoor
# 3                     -          -           -             -      1  backdoor
# 4                     -          -           -             -      1  backdoor
#
# [5 rows x 44 columns]

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#           src_ip  src_port         dst_ip  dst_port proto service   duration  \
# 0   192.168.1.33      7870  192.168.1.193     49160   tcp       -   0.000000
# 1   192.168.1.31     58593  192.168.1.186      9929   tcp       -   0.000000
# 2   192.168.1.30     60228  192.168.1.152        80   tcp    http   0.118831
# 3  192.168.1.250      5353    224.0.0.251      5353   udp     dns  39.936064
# 4   192.168.1.30     42908  192.168.1.152      2035   tcp       -   0.007056
#
#    src_bytes  dst_bytes conn_state  ...  http_response_body_len  \
# 0          0          0        OTH  ...                       0
# 1          0          0         S0  ...                       0
# 2        225       3440         SF  ...                       0
# 3        826          0         S0  ...                       0
# 4          0          0        REJ  ...                       0
#
#    http_status_code  http_user_agent  http_orig_mime_types  \
# 0                 0                -                     -
# 1                 0                -                     -
# 2                 0                -                     -
# 3                 0                -                     -
# 4                 0                -                     -
#
#    http_resp_mime_types weird_name  weird_addl  weird_notice  label  \
# 0                     -          -           -             -      1
# 1                     -          -           -             -      1
# 2                     -          -           -             -      1
# 3                     -          -           -             -      0
# 4                     -          -           -             -      1
#
#          type
# 0  ransomware
# 1    scanning
# 2   injection
# 3      normal
# 4    scanning
#
# [5 rows x 44 columns]

# %%
df.shape
# Out:
# (211043, 44)

# %%
dd= df.iloc[:50].copy()

# %%
dd.shape
# Out:
# (50, 44)

# %%
max(df['dst_bytes'])
# Out:
# 3913853482

# %%
min(df['dst_bytes'])
# Out:
# 0
