# %%
import pandas as pd
import numpy as np

# %%
path = '../data/normal_data.csv'
normal_df = pd.read_csv(path, low_memory=False)
print(normal_df.shape)
normal_df.head()
# Out:
# (796380, 47)
#            ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0  1554198358    3.122.49.24      1883  192.168.1.152     52976   tcp       -
# 1  1554198358   192.168.1.79     47260  192.168.1.255     15600   udp       -
# 2  1554198359  192.168.1.152      1880  192.168.1.152     51782   tcp       -
# 3  1554198359  192.168.1.152     34296  192.168.1.152     10502   tcp       -
# 4  1554198362  192.168.1.152     46608  192.168.1.190        53   udp     dns
#
#        duration src_bytes  dst_bytes  ... http_status_code  http_user_agent  \
# 0  80549.530260   1762852   41933215  ...                0                -
# 1      0.000000         0          0  ...                0                -
# 2      0.000000         0          0  ...                0                -
# 3      0.000000         0          0  ...                0                -
# 4      0.000549         0        298  ...                0                -
#
# ...

# %%
t_df = pd.read_csv('../data/train_test_network.csv', low_memory=False)
t_df.head()
# Out:
#           src_ip  src_port         dst_ip  dst_port proto service    duration  \
# 0   192.168.1.37      4444  192.168.1.193     49178   tcp       -  290.371539
# 1  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000102
# 2  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000148
# 3  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000113
# 4  192.168.1.193     49180   192.168.1.37      8080   tcp       -    0.000130
#
#    src_bytes  dst_bytes conn_state  ...  http_response_body_len  \
# 0     101568       2592        OTH  ...                       0
# 1          0          0        REJ  ...                       0
# 2          0          0        REJ  ...                       0
# 3          0          0        REJ  ...                       0
# 4          0          0        REJ  ...                       0
#
#    http_status_code  http_user_agent  http_orig_mime_types  \
# ...

# %%
all_df = pd.read_csv('../data/all_network_data.csv', low_memory=False)
all_df.head()
# Out:
#            ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0  1554198362  192.168.1.152     46608  192.168.1.190        53   udp     dns
# 1  1554198364  192.168.1.152     34296  192.168.1.152     10502   tcp       -
# 2  1554198374  192.168.1.152      1880  192.168.1.152     51782   tcp       -
# 3  1554198389  192.168.1.152      1880  192.168.1.152     51782   tcp       -
# 4  1554198404  192.168.1.152      1880  192.168.1.152     51782   tcp       -
#
#    duration src_bytes  dst_bytes  ... http_response_body_len  \
# 0  0.000549         0        298  ...                      0
# 1  0.000000         0          0  ...                      0
# 2  0.000000         0          0  ...                      0
# 3  0.000000         0          0  ...                      0
# 4  0.000000         0          0  ...                      0
#
#    http_status_code  http_user_agent  http_orig_mime_types  \
# 0                 0                -                     -
# ...
